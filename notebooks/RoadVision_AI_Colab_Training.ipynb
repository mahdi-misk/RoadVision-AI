# %% [markdown]
# # RoadVision-AI: Colab Training Notebook
# Train pothole and stairs detection models using YOLOv8.

# %%
# !pip install ultralytics kaggle kagglehub

# %% [markdown]
# ## Mount Google Drive
# We mount drive to save our `best.pt` safely.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## Download Datasets
# Upload your `kaggle.json` or use `kagglehub`.

# %%
import kagglehub
# path = kagglehub.dataset_download('idanbaru/annotated-potholes-with-severity-levels')
# print('Path to dataset files:', path)

# %% [markdown]
# ## Train Pothole Model

# %%
from ultralytics import YOLO
model = YOLO('yolov8n.pt')
# model.train(data='configs/pothole_data.yaml', epochs=50, imgsz=640)

# %% [markdown]
# ## Export and Copy to Drive
# Copy the `best.pt` file to your Google Drive to later deploy it on the Jetson.

# %%
# !cp runs/detect/train/weights/best.pt /content/drive/MyDrive/RoadVision_pothole_best.pt
